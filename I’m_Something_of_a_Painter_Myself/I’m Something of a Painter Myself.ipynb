# %% [markdown]
# # 1. Setup

# %% [markdown]
# ## 1.1 Required Libraries
#
# Loading all the Required Libraries for the Project.

# %%
# Standard Data Libraries
import numpy as np
import pandas as pd

# Deep Learning Libraries
import torch
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# File Operations
import os
import cv2
from tqdm import tqdm

# Plotting Libraries
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2 Global Parameters

# %%
IMG_SIZE = 256

# %% [markdown]
# ## 1.2 Device Assignment
#
# Assign GPU as main device if available, else CPU.

# %%
if torch.cuda.is_available():
    device = 'cuda'
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
else:
    device = 'cpu'

# %% [markdown]
# # 2. Data Extraction

# %%
# Base of Project Directory
BASE_DIR = "/home/akhil/Notebooks/Kaggle/I’m Something of a Painter Myself/data/"

# Input Data
folder_name = "photo_jpg"
path = os.path.join(BASE_DIR,folder_name)
input_data = []
for img in tqdm(os.listdir(path)):  # iterate over each image per photo
    try:
        img_array = cv2.imread(os.path.join(path,img))  # convert to array
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
        input_data.append([new_array, class_num])  # add this to our training_data
    except:
          print("Data could not be loaded")  
# Target Data
folder_name = "/monet_jpg"
# Out:
#   5%|▌         | 363/7038 [00:00<00:03, 1784.73it/s]
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# Data could not be loaded
# ...
